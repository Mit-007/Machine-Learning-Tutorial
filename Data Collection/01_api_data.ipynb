# %%
import pandas as pd
import requests

# %%
url = "https://stephen-king-api.onrender.com/api/books"

res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
json_data = res.json()

# %%
json_data
# Out:
# {'data': [{'id': 1,
#    'Year': 1974,
#    'Title': 'Carrie',
#    'handle': 'carrie',
#    'Publisher': 'Doubleday',
#    'ISBN': '978-0-385-08695-0',
#    'Pages': 199,
#    'Notes': [''],
#    'created_at': '2023-11-13T23:48:47.848Z',
#    'villains': [{'name': 'Tina Blake',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/4'},
#     {'name': 'Cindi',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/14'},
#     {'name': 'Myra Crewes',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/16'},
#     {'name': 'Billy deLois',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/25'},
#     {'name': 'Kenny Garson',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/38'},
#     {'name': 'Mary Lila Grace',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/44'},
#     {'name': 'Christine Hargensen',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/49'},
#     {'name': 'Vic Mooney',
# ...

# %%
# here in json_data["data"] contains all list of movie data
df = pd.json_normalize(json_data["data"])

# %%
df
# Out:
#     id  Year            Title           handle        Publisher  \
# 0    1  1974           Carrie           carrie        Doubleday
# 1    2  1975      Salem's Lot      salem-s-lot        Doubleday
# 2    3  1977      The Shining      the-shining        Doubleday
# 3    4  1977             Rage             rage     Signet Books
# 4    5  1978        The Stand        the-stand        Doubleday
# ..  ..   ...              ...              ...              ...
# 59  60  2018        Elevation        elevation         Scribner
# 60  61  2019    The Institute    the-institute         Scribner
# 61  62  2021            Later            later  Hard Case Crime
# 62  63  2021    Billy Summers    billy-summers         Scribner
# 63  72  1979  The Roopak Zone  the-roopak-zone     Viking Press
#
#                     ISBN  Pages  \
# 0      978-0-385-08695-0    199
# 1      978-0-385-00751-1    439
# 2      978-0-385-12167-5    447
# 3      978-0-451-07645-8    211
# ...

# %%
df.head()
# Out:
#    id  Year        Title       handle     Publisher               ISBN  Pages  \
# 0   1  1974       Carrie       carrie     Doubleday  978-0-385-08695-0    199
# 1   2  1975  Salem's Lot  salem-s-lot     Doubleday  978-0-385-00751-1    439
# 2   3  1977  The Shining  the-shining     Doubleday  978-0-385-12167-5    447
# 3   4  1977         Rage         rage  Signet Books  978-0-451-07645-8    211
# 4   5  1978    The Stand    the-stand     Doubleday  978-0-385-12168-2    823
#
#                                                Notes  \
# 0                                                 []
# 1            [Nominee, World Fantasy Award, 1976[2]]
# 2  [Runner-up (4th place), Locus Award for Best F...
# 3        [Published under pseudonym Richard Bachman]
# 4  [Nominee, World Fantasy Award, 1979, Runner-up...
#
#                  created_at                                           villains
# 0  2023-11-13T23:48:47.848Z  [{'name': 'Tina Blake', 'url': 'https://stephe...
# ...

# %%
url2 = "https://potterapi-fedeperin.vercel.app/en/books"

res= requests.get(url2)

res
# Out:
# <Response [200]>

# %%
json_data2 = res.json()

# %%
df2 = pd.json_normalize(json_data2)

# %%
df2
# Out:
#    number                                      title  \
# 0       1      Harry Potter and the Sorcerer's Stone
# 1       2    Harry Potter and the Chamber of Secrets
# 2       3   Harry Potter and the Prisoner of Azkaban
# 3       4        Harry Potter and the Goblet of Fire
# 4       5  Harry Potter and the Order of the Phoenix
# 5       6     Harry Potter and the Half-Blood Prince
# 6       7       Harry Potter and the Deathly Hallows
# 7       8          Harry Potter and the Cursed Child
#
#                                originalTitle   releaseDate  \
# 0      Harry Potter and the Sorcerer's Stone  Jun 26, 1997
# 1    Harry Potter and the Chamber of Secrets   Jul 2, 1998
# 2   Harry Potter and the Prisoner of Azkaban   Jul 8, 1999
# 3        Harry Potter and the Goblet of Fire   Jul 8, 2000
# 4  Harry Potter and the Order of the Phoenix  Jun 21, 2003
# 5     Harry Potter and the Half-Blood Prince  Jul 16, 2005
# 6       Harry Potter and the Deathly Hallows  Jul 21, 2007
# ...
