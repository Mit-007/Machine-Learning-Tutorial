# %% [markdown]
# # load csv & json data

# %%
import pandas as pd

# %%
df_csv = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pandas/employee_data.csv")

df_csv

# %%
print(df_csv , type(df_csv))

# %%
df_json = pd.read_json("/content/drive/MyDrive/Colab Notebooks/Pandas/emp_data.json")
df_json

# %%
print(df_json , type(df_json))
