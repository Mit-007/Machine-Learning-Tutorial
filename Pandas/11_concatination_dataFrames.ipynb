# %%
import pandas as pd

# %%
df1 = pd.DataFrame({
    "id" : [1,2],
    "name" : ["mit" , "kavy"]
})

df2 = pd.DataFrame({
    "id" : [1,2],
    "name" : ["dev" , "kishan"]
})

# %%
df1
# Out:
#    id  name
# 0   1   mit
# 1   2  kavy

# %%
df2
# Out:
#    id    name
# 0   1     dev
# 1   2  kishan

# %%
pd.concat([df1 , df2])
# Out:
#    id    name
# 0   1     mit
# 1   2    kavy
# 0   1     dev
# 1   2  kishan

# %%
pd.concat([df2,df1])
# Out:
#    id    name
# 0   1     dev
# 1   2  kishan
# 0   1     mit
# 1   2    kavy

# %%
# make new label , not copy of index of parent table
pd.concat([df1,df2] , ignore_index=True)
# Out:
#    id    name
# 0   1     mit
# 1   2    kavy
# 2   1     dev
# 3   2  kishan

# %%
pd.concat([df1,df2] , axis=1)
# Out:
#    id  name  id    name
# 0   1   mit   1     dev
# 1   2  kavy   2  kishan
