# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pandas/employee_data.csv")

df

# %% [markdown]
# # Methods Of Dataframe :

# %%
# head() : print first 5 rows
# head(n) : print first n rows

df.head()

# %%
# tail() : print last 5 rows
# tail(n) : print last n rows

df.tail()

# %%
# sample() : print random 1 rows
# sample(n) : print random n rows

df.sample()

# %%
# info() : give summary information about DF

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     object
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     object
#  4   Salary      10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes

# %%
# shape() : give (no. of rows , no. of column)
#  this is tuple , so it not a calleble like function

df.shape
# Out:
# (10, 5)

# %%
# describe() : give detailed description of numeric value columns

df.describe()
# Out:
#              ID        Age        Salary
# count  10.00000  10.000000     10.000000
# mean    5.50000  32.900000  64500.000000
# std     3.02765   6.674162  15182.226451
# min     1.00000  25.000000  47000.000000
# 25%     3.25000  28.250000  51250.000000
# 50%     5.50000  31.000000  62500.000000
# 75%     7.75000  37.250000  74250.000000
# max    10.00000  45.000000  91000.000000

# %%
# columns : list all columns name

df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
# nunique() : number of unique elements in each columns

df.nunique()
# Out:
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64
